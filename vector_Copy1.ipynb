# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinabasaha/3D-Clustering-by-matplotlib/blob/master/vector_Copy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import skfuzzy as fuzz

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(0, 0, 0, c='k', s=10) 

v1=[1,9,6]
v2=[7,8,3]
v3=[3,5,4]

ax.scatter(v1[0], v1[1], v1[2], c='r', s=50, label='vector 1', edgecolors='none') 
ax.scatter(v2[0], v2[1], v2[2], c='g', s=50, label='vector 2', edgecolors='none') 
ax.scatter(v3[0], v3[1], v3[2], c='b', s=50, label='vector 3', edgecolors='none')

#xs, ys, zs = np.meshgrid(np.arange(-10, 10, 1),
                      #np.arange(-10, 10, 1),
                      #np.arange(-10, 10, 1))


ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

#computing directions
#vector1
v1_mag=np.sqrt(v1[0]**2 + v1[1]**2 + v1[2]**2)
v1_xdirect = (v1[0]/v1_mag)
v1_ydirect = (v1[1]/v1_mag)
v1_zdirect = (v1[2]/v1_mag)


#vector2
v2_mag=np.sqrt(v2[0]**2 + v2[1]**2 + v2[2]**2)
v2_xdirect = (v2[0]/v2_mag)
v2_ydirect = (v2[1]/v2_mag)
v2_zdirect = (v2[2]/v2_mag)


#vector1
v3_mag=np.sqrt(v3[0]**2 + v3[1]**2 + v3[2]**2)
v3_xdirect = (v3[0]/v3_mag)
v3_ydirect = (v3[1]/v3_mag)
v3_zdirect = (v3[2]/v3_mag)

#ax.axis(xmin=0, xmax=100)
#ax.axis(ymin=0, ymax=100)
#ax.axis(zmin=0, zmax=100)
#ax.scatter(0, 0, 0, c='k', s=10) 
ax.quiver(0, 0, 0, v1_xdirect, v1_ydirect, v1_zdirect, length = v1_mag, normalize = True, color='r')
ax.quiver(0, 0, 0, v2_xdirect, v2_ydirect, v2_zdirect, length = v2_mag, normalize = True, color='g')
ax.quiver(0, 0, 0, v3_xdirect, v3_ydirect, v3_zdirect, length = v3_mag, normalize = True, color='b')

#plt.quiver(0, 0, 0, 1, 1, 1, scale=1, color='g')
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
X1=9*v3_xdirect
Y1=9*v3_ydirect
Z1=9*v3_zdirect

v4=[X1, Y1, Z1]
v4
# Out:
# [3.8183766184073566, 6.363961030678928, 5.091168824543142]

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(0, 0, 0, c='k', s=10) 

ax.scatter(v1[0], v1[1], v1[2], c='r', s=50, label='vector 1', edgecolors='none') 
ax.scatter(v2[0], v2[1], v2[2], c='g', s=50, label='vector 2', edgecolors='none') 
ax.scatter(v3[0], v3[1], v3[2], c='b', s=50, label='vector 3', edgecolors='none')
ax.scatter(v4[0], v4[1], v4[2], c='k', s=50, label='vector 4', edgecolors='none')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')


#vector_4
v4_mag=np.sqrt(v4[0]**2 + v4[1]**2 + v4[2]**2)
v4_xdirect = (v4[0]/v4_mag)
v4_ydirect = (v4[1]/v4_mag)
v4_zdirect = (v4[2]/v4_mag)


ax.quiver(0, 0, 0, v1_xdirect, v1_ydirect, v1_zdirect, length = v1_mag, normalize = True, color='r')
ax.quiver(0, 0, 0, v2_xdirect, v2_ydirect, v2_zdirect, length = v2_mag, normalize = True, color='g')
ax.quiver(0, 0, 0, v3_xdirect, v3_ydirect, v3_zdirect, length = v3_mag, normalize = True, color='b')
ax.quiver(0, 0, 0, v4_xdirect, v4_ydirect, v4_zdirect, length = v4_mag, normalize = True, color='k')

ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
v_new = [4.5, 6, 3]

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(0, 0, 0, c='k', s=10) 

ax.scatter(v1[0], v1[1], v1[2], c='r', s=50, label='vector 1', edgecolors='none') 
ax.scatter(v2[0], v2[1], v2[2], c='g', s=50, label='vector 2', edgecolors='none') 
ax.scatter(v3[0], v3[1], v3[2], c='b', s=50, label='vector 3', edgecolors='none')
ax.scatter(v4[0], v4[1], v4[2], c='k', s=50, label='vector 4', edgecolors='none')
ax.scatter(v_new[0], v_new[1], v_new[2], c='y', s=50, label='new vector', edgecolors='none')


ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

#Computing direction of new vector
v_new_mag=np.sqrt(v_new[0]**2 + v_new[1]**2 + v_new[2]**2)
v_new_xdirect = (v_new[0]/v_new_mag)
v_new_ydirect = (v_new[1]/v_new_mag)
v_new_zdirect = (v_new[2]/v_new_mag)


ax.quiver(0, 0, 0, v1_xdirect, v1_ydirect, v1_zdirect, length = v1_mag, normalize = True, color='r')
ax.quiver(0, 0, 0, v2_xdirect, v2_ydirect, v2_zdirect, length = v2_mag, normalize = True, color='g')
ax.quiver(0, 0, 0, v3_xdirect, v3_ydirect, v3_zdirect, length = v3_mag, normalize = True, color='b')
ax.quiver(0, 0, 0, v4_xdirect, v4_ydirect, v4_zdirect, length = v4_mag, normalize = True, color='k')
#ax.quiver(0, 0, 0, v_new_xdirect, v_new_ydirect, v_new_zdirect, length = V4_mag, normalize = True, color='k')


#plt.quiver(0, 0, 0, 1, 1, 1, scale=1, color='g')
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
s=[]
m=[]
l=[]

V1=np.asarray(v1)
V2=np.asarray(v2)
V3=np.asarray(v3)
V4=np.asarray(v4)
V_new=np.asarray(v_new)

s1=fuzz.smf(V1, -4.0, 0.0)
m1=fuzz.smf(V1, 1.0, 5.5)
l1=fuzz.smf(V1, 5.0, 5.0)

s2=fuzz.smf(V2, -4.0, 0.0)
m2=fuzz.smf(V2, 1.0, 5.5)
l2=fuzz.smf(V2, 5.0, 5.0)

s3=fuzz.smf(V3, -4.0, 0.0)
m3=fuzz.smf(V3, 1.0, 5.5)
l3=fuzz.smf(V3, 5.0, 5.0)

s4=fuzz.smf(V4, -4.0, 0.0)
m4=fuzz.smf(V4, 1.0, 5.5)
l4=fuzz.smf(V4, 5.0, 5.0)

s3=fuzz.smf(V_new, -4.0, 0.0)
m3=fuzz.smf(V_new, 1.0, 5.5)
l3=fuzz.smf(V_new, 5.0, 5.0)
# Out:
# /home/ai_lab2/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/skfuzzy/membership/generatemf.py:371: RuntimeWarning: invalid value encountered in true_divide
#   y[idx] = 2. * ((x[idx] - a) / (b - a)) ** 2.
# /home/ai_lab2/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/skfuzzy/membership/generatemf.py:374: RuntimeWarning: invalid value encountered in true_divide
#   y[idx] = 1 - 2. * ((x[idx] - b) / (b - a)) ** 2.
